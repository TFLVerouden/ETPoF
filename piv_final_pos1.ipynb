# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sig
import piv_fun as piv

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Parameters
position_nr = 1
series_nrs = [3, 4, 7]
margins_all = [[0, 0, 0, 0],
               [48, 496 - 443, 0, 0],
               [60, 496 - 452, 0, 0],
               [10, 496 - 480, 0, 0],
               [0, 0, 128, 0]]
max_shift_px = 100
slice_ct = 8
window_ct = (24, 32)

# Start batch PIV
piv.batch_optical_flow(position_nr, series_nrs, slice_ct, window_ct,
                       max_shift_px, margins_all[position_nr])
# Out:
# Processing pos1-3
# -----------------
# Reading images: 100%|██████████| 7500/7500 [00:12<00:00, 589.70it/s]
# Subtracting background: 100%|██████████| 7500/7500 [00:14<00:00, 507.70it/s]
# Optical flow: 100%|██████████| 7499/7499 [09:12<00:00, 13.57it/s]
# Processing pos1-4
# -----------------
# Reading images: 100%|██████████| 14511/14511 [00:15<00:00, 911.48it/s]
# Subtracting background: 100%|██████████| 14511/14511 [00:20<00:00, 714.00it/s]
# Optical flow: 100%|██████████| 14510/14510 [14:38<00:00, 16.51it/s]
# Processing pos1-7
# -----------------
# Reading images: 100%|██████████| 10301/10301 [00:10<00:00, 997.26it/s]
# Subtracting background: 100%|██████████| 10301/10301 [00:15<00:00, 674.70it/s]
# Optical flow: 100%|██████████| 10300/10300 [10:28<00:00, 16.40it/s]

# %%
# Parameters
position_nr = 1
series_nrs = [2, 5, 6]
margins_all = [[0, 0, 0, 0],
               [48, 496 - 443, 0, 0],
               [60, 496 - 452, 0, 0],
               [10, 496 - 480, 0, 0],
               [0, 0, 128, 0]]
max_shift_px = 100
slice_ct = 8
window_ct = (24, 32)

# Start batch PIV
piv.batch_optical_flow(position_nr, series_nrs, slice_ct, window_ct,
                       max_shift_px, margins_all[position_nr])
# Out:
# Processing pos1-2
# -----------------
# Reading images: 100%|██████████| 7166/7166 [00:11<00:00, 608.85it/s]
# Subtracting background: 100%|██████████| 7166/7166 [00:12<00:00, 591.13it/s]
# Optical flow: 100%|██████████| 7165/7165 [07:50<00:00, 15.22it/s]
# Processing pos1-5
# -----------------
# Reading images: 100%|██████████| 8760/8760 [00:08<00:00, 1020.50it/s]
# Subtracting background: 100%|██████████| 8760/8760 [00:11<00:00, 756.61it/s]
# Optical flow: 100%|██████████| 8759/8759 [09:16<00:00, 15.75it/s]
# Processing pos1-6
# -----------------
# Reading images: 100%|██████████| 9397/9397 [00:14<00:00, 663.69it/s]
# Subtracting background: 100%|██████████| 9397/9397 [00:13<00:00, 703.68it/s]
# Optical flow: 100%|██████████| 9396/9396 [09:30<00:00, 16.48it/s]
