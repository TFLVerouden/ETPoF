# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pof_piv as piv
window_counts = (25, 8)

# %% [markdown]
# ### Position 1

# %%
position = 1
margins1 = (48, 53, 0, 0)

# %%
displacements1_3, _ = piv.video_piv(position, 3, window_counts, 
                                    margins=margins1, save=True, plot=True)
# Out:
# Reading images:  31%|███       | 2327/7500 [00:02<00:05, 1016.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 displacements1_3, _ = piv.video_piv(position, 3, window_counts,
#       2                                     margins=margins1, save=True, plot=True)
#
# File ~/PycharmProjects/ETPoF/pof_piv/pof_piv/piv_functions.py:145, in video_piv(position_nr, series_nr, window_counts, frame_rate, cutoff, margins, save, plot)
#     142 series_name = 'pos' + str(position_nr) + '-' + str(series_nr)
#     143 directory = 'data/' + series_name
# --> 145 images = read_image_directory(directory, image_type='tif', timing=True)
#     146 background = cv.imread('data/backgrounds/' + series_name + '.tif',
#     147                        cv.IMREAD_GRAYSCALE)
#     149 # Subtract the background from all images
#
# ...

# %%
displacements1_4, _ = piv.video_piv(position, 4, window_counts, 
                                    margins=margins1, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 14510/14510 [06:33<00:00, 36.91it/s]
# /Users/tommieverouden/PycharmProjects/ETPoF/pof_piv/pof_piv/piv_functions.py:215: RuntimeWarning: Mean of empty slice
#   mean_displ[i] = np.nanmean(

# %%
displacements1_7, _ = piv.video_piv(position, 7, window_counts, 
                                    margins=margins1, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 10300/10300 [04:16<00:00, 40.23it/s]

# %% [markdown]
# ### Position 2

# %%
position = 2
margins2 = (60, 44, 0, 0)

# %%
displacements2_2, _ = piv.video_piv(position, 2, window_counts,
                                    margins=margins2, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 15560/15560 [07:02<00:00, 36.81it/s]

# %%
displacements2_3, _ = piv.video_piv(position, 3, window_counts,
                                    margins=margins2, save=True, plot=True)
# Out:
# ...
#  78%|███████▊  | 13914/17893 [06:01<01:33, 42.39it/s]/Users/tommieverouden/PycharmProjects/ETPoF/pof_piv/pof_piv/helper_functions.py:169: RuntimeWarning: invalid value encountered in scalar divide
#   correction = [(0.5 * (np.log(neighbor[0]) - np.log(neighbor[2]))
# 100%|██████████| 17893/17893 [07:44<00:00, 38.54it/s]

# %%
displacements2_4, _ = piv.video_piv(position, 4, window_counts,
                                    margins=margins2, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 13083/13083 [05:54<00:00, 36.96it/s]

# %% [markdown]
# ### Position 3

# %%
position = 3
margins3 = (10, 16, 0, 0)

# %%
displacements3_1, _ = piv.video_piv(position, 1, window_counts,
                                    margins=margins3, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 25052/25052 [13:17<00:00, 31.42it/s]

# %%
displacements3_2, _ = piv.video_piv(position, 2, window_counts,
                                    margins=margins3, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 19834/19834 [15:02<00:00, 21.98it/s]

# %%
displacements3_3, _ = piv.video_piv(position, 3, window_counts,
                                    margins=margins3, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 26715/26715 [17:06<00:00, 26.02it/s]

# %% [markdown]
# ### Position 4

# %%
position = 4
margins4 = (0, 0, 128, 0)

displacements4_1, _ = piv.video_piv(position, 1, window_counts, 
                                    margins=margins4, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 15237/15237 [06:58<00:00, 36.38it/s]

# %%
displacements4_2, _ = piv.video_piv(position, 2, window_counts, 
                                    margins=margins4, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 12932/12932 [06:02<00:00, 35.72it/s]

# %%
displacements4_3, _ = piv.video_piv(position, 3, window_counts, 
                                    margins=margins4, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 21040/21040 [09:50<00:00, 35.65it/s]

# %%
displacements4_4, _ = piv.video_piv(position, 4, window_counts, 
                                    margins=margins4, save=True, plot=True)
# Out:
# ...
# 100%|██████████| 20994/20994 [09:49<00:00, 35.60it/s]
