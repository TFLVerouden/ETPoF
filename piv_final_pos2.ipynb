# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sig
import piv_fun as piv

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Parameters
position_nr = 2
series_nrs = [2, 3, 4]
margins_all = [[0, 0, 0, 0],
               [48, 496 - 443, 0, 0],
               [60, 496 - 452, 0, 0],
               [10, 496 - 480, 0, 0],
               [0, 0, 128, 0]]
max_shift_px = 100
slice_ct = 8
window_ct = (24, 32)

# Start batch PIV
piv.batch_optical_flow(position_nr, series_nrs, slice_ct, window_ct,
                       max_shift_px, margins_all[position_nr])
# Out:
# Processing pos2-2
# -----------------
# Reading images: 100%|██████████| 15561/15561 [00:28<00:00, 546.74it/s]
# Subtracting background: 100%|██████████| 15561/15561 [00:41<00:00, 372.98it/s]
# Optical flow: 100%|██████████| 15560/15560 [17:37<00:00, 14.71it/s]
# Processing pos2-3
# -----------------
# Reading images: 100%|██████████| 17894/17894 [00:19<00:00, 894.86it/s]
# Subtracting background: 100%|██████████| 17894/17894 [00:26<00:00, 676.92it/s]
# Optical flow: 100%|██████████| 17893/17893 [20:23<00:00, 14.63it/s]
# Processing pos2-4
# -----------------
# Reading images: 100%|██████████| 13084/13084 [00:16<00:00, 785.88it/s]
# Subtracting background: 100%|██████████| 13084/13084 [00:20<00:00, 653.43it/s]
# Optical flow: 100%|██████████| 13083/13083 [14:38<00:00, 14.89it/s]
