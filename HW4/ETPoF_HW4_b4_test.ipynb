# %%
import pof_piv as piv
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import os
from natsort import natsorted
from natsort import index_natsorted
import scipy.signal as sig
from tqdm import trange
from tqdm import tqdm

# %%
directory = 'PIVimages/Suboptimal/'
file_prefix = None
file_type = 'png'

images_sets, set_names = piv.read_image_sets(directory, file_prefix, file_type, grouping=True)

# %%
i = 5

plot_params = {'arrow_scale':            3,
               'plot_windows':           False,
               'title':                  set_names[i]}

displacements, coordinates = piv.simple_piv(images_sets[i], 25, plot=True, plt_flow_params=plot_params, plt_disp_params=plot_params)

# %% [markdown]
# Uneven lighting goes well (as expected with PIV),
# Leaky particles could be solved with outlier removal, bigger windows

# %% [markdown]
# Refer to rules of thumb!
